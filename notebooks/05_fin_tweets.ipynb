# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("../data/financial_tweets/financial_tweets_sentiments.csv")
df.head()
# Out:
#     timestamp                                        description  sentiment
# 0  2021-12-27  RT @Amdtrades: $MANA Not bad so far $MANA Not ...  -0.035238
# 1  2022-01-02  $YFI Weekly close. update on $YFI\n\n~.85$ ✅\n...   0.056101
# 2  2022-01-03  the $BTCD collapsed because the $TOTAL 2 is ho...   0.071395
# 3  2022-01-04  $CRV $SRM\n\nLooking for this new 1D UCTS Buy ...   0.019129
# 4  2022-01-05  $FTM cares zero about your sell off $LINK PAIR...  -0.028683

# %%
plt.plot(df["sentiment"], color="black")
